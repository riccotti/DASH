# %%
import matplotlib.pyplot as plt

import sys
sys.path.append('../')

from util import *
from config import *

from gendis.genetic import GeneticExtractor

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
# Out:
# Using TensorFlow backend.
# /Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/deap/tools/_hypervolume/pyhv.py:33: ImportWarning: Falling back to the python version of hypervolume module. Expect this to be very slow.
#   "module. Expect this to be very slow.", ImportWarning)
# /Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.cluster.k_means_ module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %%
#dataset = 'italypower'  # ts_datasets[0]
#window_sizes = [2, 4, 6]
#window_steps = [1, 1, 1]
#n_shapelets = 10
#n_clusters = 5
#
# dataset = 'gunpoint'  # ts_datasets[0]
# window_sizes = [5, 10, 20]
# window_steps = [1, 5, 10]
# n_shapelets = 5
# n_clusters = 3
#
# dataset = 'arrowhead'  # ts_datasets[0]
# window_sizes = [5, 10, 20]
# window_steps = [1, 5, 10]
# n_shapelets = 5
# n_clusters = 3
#
# dataset = 'ecg200'  # ts_datasets[0]
# window_sizes = [5, 10, 20]
# window_steps = [1, 2, 5]
# n_shapelets = 5
# n_clusters = 3
#
# dataset = 'ecg5000'  # ts_datasets[0]
# window_sizes = [5, 10, 20]
# window_steps = [1, 2, 5]
# n_shapelets = 5
# n_clusters = 2
#
# dataset = 'electricdevices'  # ts_datasets[0]
# window_sizes = [5, 10, 20]
# window_steps = [1, 2, 5]
# n_shapelets = 5
#
dataset = 'phalanges'  # ts_datasets[0]
window_sizes = [5, 10, 20]
window_steps = [1, 2, 5]
n_shapelets = 5

clustering = 'rnd'
random_state = None
n_jobs = -1
verbose = 1

D = get_dataset(dataset, path_dataset, normalize)
X_train, y_train, X_test, y_test = D['X_train'], D['y_train'], D['X_test'], D['y_test']
n_classes = D['n_classes']

genetic_extractor = GeneticExtractor(population_size=50, iterations=25, verbose=True,
                                     normed=False, n_jobs=-1, max_len=window_sizes[-1])

shapelets = genetic_extractor.fit(X_train, y_train)

# print(dase.shapelets_)
# print(dase.indices_)
# print(dase.scores_)

for s in shapelets:
     plt.plot(s)
plt.show()

X_train_d = genetic_extractor.transform(X_train)
X_test_d = genetic_extractor.transform(X_test)

print(' --- DT --- ')

max_depth = max(4, int(np.ceil(np.log2(n_classes))))

clf = DecisionTreeClassifier(max_depth=max_depth)
clf.fit(X_train_d, y_train)

print(accuracy_score(y_train, clf.predict(X_train_d)))
print(accuracy_score(y_test, clf.predict(X_test_d)))

clf = DecisionTreeClassifier(max_depth=max_depth)
clf.fit(X_train, y_train)

print(accuracy_score(y_train, clf.predict(X_train)))
print(accuracy_score(y_test, clf.predict(X_test)))

print(' --- 1NN --- ')

clf = KNeighborsClassifier(n_neighbors=1)
clf.fit(X_train_d, y_train)

print(accuracy_score(y_train, clf.predict(X_train_d)))
print(accuracy_score(y_test, clf.predict(X_test_d)))

clf = KNeighborsClassifier(n_neighbors=1)
clf.fit(X_train, y_train)

print(accuracy_score(y_train, clf.predict(X_train)))
print(accuracy_score(y_test, clf.predict(X_test)))

print(' --- LR --- ')

clf = LogisticRegression()
clf.fit(X_train_d, y_train)

print(accuracy_score(y_train, clf.predict(X_train_d)))
print(accuracy_score(y_test, clf.predict(X_test_d)))

clf = LogisticRegression()
clf.fit(X_train, y_train)

print(accuracy_score(y_train, clf.predict(X_train)))
print(accuracy_score(y_test, clf.predict(X_test)))
# Out:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-8:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/gendis/genetic.py", line 291, in <lambda>
#     cache=cache))
#   File "/Users/riccardo/Documents/ExplainingPairwiseLearning/code/idacs/gendis/fitness.py", line 22, in logloss_fitness
#     _pdist(X, [shap.flatten() for shap in shapelets], D)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "gendis/pairwise_dist.pyx", line 26, in gendis.pairwise_dist._pdist
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 1966, in sum
#     @array_function_dispatch(_sum_dispatcher)
# KeyboardInterrupt
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/gendis/genetic.py", line 291, in <lambda>
#     cache=cache))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-4:
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/gendis/genetic.py", line 291, in <lambda>
#     cache=cache))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/riccardo/Documents/ExplainingPairwiseLearning/code/idacs/gendis/fitness.py", line 22, in logloss_fitness
#     _pdist(X, [shap.flatten() for shap in shapelets], D)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/riccardo/Documents/ExplainingPairwiseLearning/code/idacs/gendis/fitness.py", line 22, in logloss_fitness
#     _pdist(X, [shap.flatten() for shap in shapelets], D)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "gendis/pairwise_dist.pyx", line 26, in gendis.pairwise_dist._pdist
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/gendis/genetic.py", line 291, in <lambda>
#     cache=cache))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/gendis/genetic.py", line 291, in <lambda>
#     cache=cache))
#   File "gendis/pairwise_dist.pyx", line 26, in gendis.pairwise_dist._pdist
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/gendis/genetic.py", line 291, in <lambda>
#     cache=cache))
#   File "/Users/riccardo/Documents/ExplainingPairwiseLearning/code/idacs/gendis/fitness.py", line 22, in logloss_fitness
#     _pdist(X, [shap.flatten() for shap in shapelets], D)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/gendis/genetic.py", line 291, in <lambda>
#     cache=cache))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2076, in sum
#     initial=initial)
#   File "/Users/riccardo/Documents/ExplainingPairwiseLearning/code/idacs/gendis/fitness.py", line 22, in logloss_fitness
#     _pdist(X, [shap.flatten() for shap in shapelets], D)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 1966, in sum
#     @array_function_dispatch(_sum_dispatcher)
#   File "/Users/riccardo/Documents/ExplainingPairwiseLearning/code/idacs/gendis/fitness.py", line 22, in logloss_fitness
#     _pdist(X, [shap.flatten() for shap in shapelets], D)
#   File "gendis/pairwise_dist.pyx", line 26, in gendis.pairwise_dist._pdist
#   File "/Users/riccardo/Documents/ExplainingPairwiseLearning/code/idacs/gendis/fitness.py", line 22, in logloss_fitness
#     _pdist(X, [shap.flatten() for shap in shapelets], D)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 1966, in sum
#     @array_function_dispatch(_sum_dispatcher)
# KeyboardInterrupt
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 69, in _wrapreduction
#     def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#   File "gendis/pairwise_dist.pyx", line 26, in gendis.pairwise_dist._pdist
#   File "gendis/pairwise_dist.pyx", line 26, in gendis.pairwise_dist._pdist
# KeyboardInterrupt
# KeyboardInterrupt
#   File "gendis/pairwise_dist.pyx", line 26, in gendis.pairwise_dist._pdist
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 1966, in sum
#     @array_function_dispatch(_sum_dispatcher)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2062, in sum
#     if isinstance(a, _gentype):
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2076, in sum
#     initial=initial)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/gendis/genetic.py", line 291, in <lambda>
#     cache=cache))
#   File "/Users/riccardo/Documents/ExplainingPairwiseLearning/code/idacs/gendis/fitness.py", line 22, in logloss_fitness
#     _pdist(X, [shap.flatten() for shap in shapelets], D)
#   File "gendis/pairwise_dist.pyx", line 26, in gendis.pairwise_dist._pdist
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2076, in sum
#     initial=initial)
#   File "/Users/riccardo/opt/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-3526dcb90098> in <module>
#      51                                      normed=False, n_jobs=-1, max_len=window_sizes[-1])
#      52
# ---> 53 shapelets = genetic_extractor.fit(X_train, y_train)
#      54
#      55 # print(dase.shapelets_)
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/gendis/genetic.py in fit(self, X, y)
#     370             start = time.time()
#     371             invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
# --> 372             fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
#     373             for ind, fit in zip(invalid_ind, fitnesses):
#     374                 ind.fitness.values = fit
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pathos/multiprocessing.py in map(self, f, *args, **kwds)
#     135         AbstractWorkerPool._AbstractWorkerPool__map(self, f, *args, **kwds)
#     136         _pool = self._serve()
# --> 137         return _pool.map(star(f), zip(*args)) # chunksize
#     138     map.__doc__ = AbstractWorkerPool.map.__doc__
#     139     def imap(self, f, *args, **kwds):
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/multiprocess/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
